# %% [markdown]
# # {Algorithm} — {Stage}
#
# **Goal.** One sentence on what this notebook delivers.
#
# **Prerequisites.** Notebook(s) in the same folder that must be read first (e.g. `01_intuition.ipynb`).
#
# **Stage map.** `01_intuition` → `02_mathematics` → `03_optimization` → `04_statistics` → `05_hands_on_programming`.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import random

import numpy as np
import matplotlib.pyplot as plt

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
rng = np.random.default_rng(SEED)

# import torch
# torch.manual_seed(SEED)
# torch.cuda.manual_seed_all(SEED)

plt.rcParams["figure.dpi"] = 90

# %% [markdown]
# ## 1. Section heading
#
# Content here.

# %% [markdown]
# ## Takeaway
#
# - Bullet 1
# - Bullet 2
#
# Next: `0X_next_step.ipynb`.
