# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hien078/Machine-Learning-from-scratch/blob/master/_template_first_principles.ipynb)
#
# # [Topic Name] — First Principles
#
# > **Status:** ⚪ Planned | **Phase:** X | **Prerequisites:** [list]
#
# ---

# %% [markdown]
# ## 0. Prerequisites
#
# - See [theory.md](./theory.md) for pure definitions and derivations
# - See [applied-mathematics-foundation](https://github.com/hien078/applied-mathematics-foundation) for mathematical background
# - Required: [list specific foundation notebooks]

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# %load_ext autoreload
# %autoreload 2

SEED = 42
random.seed(SEED)
rng = np.random.default_rng(SEED)

plt.rcParams["figure.dpi"] = 90

# %% [markdown]
# ## 1. Problem Setup — WHY
#
# Brief recap of the problem (2-3 sentences, not full derivation — see theory.md).
# Show the problem with data:

# %%
# Generate synthetic data demonstrating the problem
# TODO: Create a visual that shows WHY this method is needed

# %% [markdown]
# ## 2. Mathematical Core — WHAT
#
# Key equations with code verification.
# NOT full derivation — reference theory.md for that.
#
# $$\text{[Key equation here]}$$

# %%
# Verify the key equation numerically
# TODO: Code that checks the math

# %% [markdown]
# ## 3. Solution Method — HOW
#
# Derivation of the algorithm with code checking each step.
# Closed-form vs iterative comparison if applicable.

# %%
# Step-by-step derivation with code
# TODO: Show each derivation step verified by code

# %% [markdown]
# ## 4. Implementation — BUILD
#
# NumPy implementation from scratch. Can import reusable classes from `src/`.

# %%
# From-scratch NumPy implementation
# TODO: Implement the algorithm

class ModelName:
    def __init__(self):
        pass
    
    def fit(self, X, y):
        pass
    
    def predict(self, X):
        pass

# %% [markdown]
# ## 5. Library Comparison
#
# Compare with sklearn/PyTorch. Assert numerical consistency.

# %%
# Compare with sklearn
# from sklearn.linear_model import ...
# TODO: Assert our implementation matches sklearn

# %% [markdown]
# ## 6. Experiments — VERIFY
#
# Synthetic data, edge cases, noise, failure modes, visualizations.

# %%
# Experiment 1: Basic synthetic data
# TODO: Show model working on clean data

# Experiment 2: Edge cases
# TODO: Show what happens with noise, outliers, etc.

# Experiment 3: Failure cases
# TODO: Show when and why the model fails

# %% [markdown]
# ## 7. Intuition Summary
#
# **One paragraph:** [Summarize the key idea in simple terms]
#
# **Key visual:** [One diagram or plot that captures the essence]

# %% [markdown]
# ## 8. Connections
#
# - **Prerequisites:** [list prerequisite nodes]
# - **Foundations:** [list foundation nodes with links]
# - **Related Topics:** [list related topic nodes]
# - **Synthesis:** [list relevant synthesis documents]
# - **Projects:** [list projects that apply this topic]
# - **Graph Map:** See [INDEX.md](INDEX.md)

# %% [markdown]
# ## 9. Exercises
#
# See [exercises.ipynb](./exercises.ipynb) for practice problems.
#
# ### Quick check:
# 1. [Hand-calc question]
# 2. [Coding question]
# 3. [Conceptual question]
